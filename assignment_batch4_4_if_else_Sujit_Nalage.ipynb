# %% [markdown]
# ### 1. Write a program to check if a number is positive.

# %%
a = 3
if a > 0:
    print("It is possitive no")
else:
    print("It is negative no")
# Out:
# It is possitive no

# %% [markdown]
# ### 2. Check if a number is even or odd.

# %%
a = 5
if a % 2 == 0:
    print("It is even no")
else:
    print("It is odd no")
# Out:
# It is odd no

# %% [markdown]
# ### 3. Check if a person is eligible to vote (age >= 18).

# %%
a = 19
if a > 18:
    print("person is eligible to voting")
else:
    print("person is not eligible to voting")
# Out:
# person is eligible to voting

# %% [markdown]
# ### 4. Check if a number is greater than 100.

# %%
a = 101
if a > 100:
    print("It is large no")
else:
    print("It is small no")
# Out:
# It is large no

# %% [markdown]
# ### 5. Print “Adult” if age > 18 else print “Child”.

# %%
a = 17
if a > 18:
    print("Adult age person")
else:
    print("It is childhood")
# Out:
# It is childhood

# %% [markdown]
# ### 6. Check if two numbers are equal.

# %%
a = int(input())
if a == 3:
    print("It is equal no")
else:
    print("It is not equal no")
# Out:
# It is equal no

# %% [markdown]
# ### 7. Check if a number is divisible by 5.

# %%
a = int(input())
if a % 5 == 0:
    print("It is divisibal no")
else:
    print("It is not divisibal no")
# Out:
# It is divisibal no

# %% [markdown]
# ### 8. Check if a string is “hello”.

# %%
a = input()
if a == "hello":
    print("Is True")
else:
    print("Is False")
# Out:
# Is True

# %% [markdown]
# ### 9. Print the larger of two numbers.

# %%
a = 10
b = 20

print(max(a, b))
# Out:
# 20

# %% [markdown]
# ### 10. Check if a number is negative

# %%
a = int(input())
if a < 0:
    print("Is Negative No")
else:
    print("Is Possitive No")
# Out:
# Is Negative No

# %% [markdown]
# ### 11. Check if a number is positive, negative, or zero.

# %%
a = int(input())
if a > 0:
    print("no is positive")
elif a < 0:
     print("no is negative")
else:
    print("Zero")
# Out:
# no is negative

# %% [markdown]
# ### 12. Check if a year is a leap year.

# %%
a = int(input("YEAR"))
if a % 4 == 0:
    print("It is leap year")
else:
    print("It is not leap year")
# Out:
# It is leap year

# %% [markdown]
# ### 13. Check if a character is a vowel or consonant.

# %%
a = input()
if a == "a" or a=="e" or a=="i" or a=="o" or a=="u":
    print("Is Vovel")
else:
    print("Is Consonant")
# Out:
# Is Consonant

# %% [markdown]
# ### 14. Print the greatest of three numbers.

# %%
gr = [1,2,3]
max(gr)
# Out:
# 3

# %% [markdown]
# ### 15. Check if a password length is strong (>= 8).

# %%
a = int(input())
if a >= 8:
    print("It is a strong password")
else:
    print("please create strong password")
# Out:
# It is a strong password

# %% [markdown]
# ### 16. Check if a number lies between 10 and 50.

# %%
cv = int(input())
if cv >= 10 and cv <= 50:
    print("No is between 10 and 50")
else:
    print("please enter correct no")
# Out:
# No is between 10 and 50

# %% [markdown]
# ### 17. Print the grade of a student (A, B, C, D, F) based on marks.

# %%
marks = int(input())
if marks > 90:
    print("A Grade")
elif marks > 75 and marks < 90:
    print("B Grade")
elif marks > 65 and marks < 75:
    print("C Grade")
elif marks > 35 and marks < 65:
    print("D Grade")
else:
    print("D Grade And Failed")
# Out:
# D Grade And Failed

# %% [markdown]
# ### 18. Check if a number is divisible by both 2 and 3.

# %%
by = int(input())
if by % 2 == 0 and by%3 == 0:
    print("Devided")
else:
    print("please enter divisible no")
# Out:
# Devided

# %% [markdown]
# ### 19. Check if a person’s age falls into categories: child, teen, adult, senior.

# %%
re = int(input())
if re > 60 :
    print("Senior Person")
elif re > 18 :
    print("Adult Person")
elif re > 7 :
    print("Teen Person")
else :
    print("Child")
# Out:
# Child

# %% [markdown]
# ### 20. Check if a character is uppercase or lowercase.

# %%
hn  =input("Enter String")

# if hn.startswith(hn[0].upper()):
#     print("Is Upper Case")
# else:
#     print("Is lower case")

if hn.isupper():
    print("Is Upper Case")
elif hn.islower():
    print("Is Lower case")
# Out:
# Is Lower

# %% [markdown]
# ### 21. Check if a number is a multiple of 10.

# %%
a = int(input())
if a % 10 == 0:
    print("Done It")
else:
    print("wrong ans")
# Out:
# Done It

# %% [markdown]
# ### 22. Compare two numbers and print “greater”, “smaller”, or “equal”.

# %%
a = int(input())
b = int(input())

maximum = max(a , b)
minimum = min(a, b)
if a == b:
    print("This are equal numbers")
else:
    print(maximum, "is the maximum number")
    print(minimum, "Is the minimum number")
# Out:
# 15 is the maximum number
# 13 Is the minimum number

# %% [markdown]
# ### 23. Check if a triangle is equilateral, isosceles, or scalene.

# %%
a=17
b=10
c=17
 
if a == b and b == c and a == c :
    print("equilateral triangle")
elif a==b or b==c or a==c:
    print("isosceles triangle")
else:
    print("scalene")
# Out:
# isosceles triangle

# %% [markdown]
# ### 24. Check if a string contains the word “python”.

# %%
a = input()

if "python" in a:
    print("Is correct")
else:
    print("Is Wrong")
# Out:
# Is correct

# %% [markdown]
# ### 25. Check if a list has more than 5 elements.

# %%
js= [1,2,3,4,5,6,7,89,4]
if len(js)> 5:
    print("Is Correct")
else:
    print("Is Wrong")
# Out:
# Is Correct

# %% [markdown]
# ### 26. Check if temperature is cold (<15), warm (15–30), or hot (>30).

# %%
yh = int(input())
if  yh < 15:
    print("COLD")
elif yh > 15 and yh < 30:
    print("WARM")
else: 
    print("HOT")
# Out:
# HOT

# %% [markdown]
# ### 27. Check if a student passed (marks >= 40) else fail.

# %%
marks = int(input())
if marks >= 40:
     print("Passed")
else:
     print("Fail")
# Out:
# Fail

# %% [markdown]
# ### 28. Check if a number ends with digit 7.

# %%
num = int(input())

a = num % 10

if a == 7:
    print("Number is end with 7")
else:
    print("Number is not end with 7")
# Out:
# Number is not end with 7

# %% [markdown]
# ### 29. Check if the first character of a string is a vowel.

# %%
a = input()
if  a.startswith("a") or a.startswith("e") or a.startswith("i") or a.startswith("o") or a.startswith("u"):
    print("Is start with Vovel")
else:
    print("Is not start with vovel")
# Out:
# Is start with Vovel

# %% [markdown]
# ### 30. Check if a number is within 1 to 100, else print “out of range

# %%
a = int(input())
if a >= 1 and a<= 100:
    print("CORRECTED")
else:
    print("OUT OF RANGE")
# Out:
# OUT OF RANGE

# %% [markdown]
# ### 31. Check if a number is prime using if-else (simple logic allowed).

# %% [markdown]
# ### 32. Check if the last digit of a number is even or odd.

# %%
num = int(input())
a = num % 10

if a % 2 == 0:
    print("It is even no")
else:
    print("It is odd no")
# Out:
# It is odd no

# %% [markdown]
# ### 33. Check if the input is an integer or not (using string checks).

# %%
s = input("Enter something: ")

if s.isdigit():
    print("It is an integer")
else:
    print("It is not an integer")
# Out:
# It is not an integer

# %% [markdown]
# ### 34. Check if three angles can form a valid triangle.

# %%
a = int(input("First"))
b = int(input("Second"))
c = int(input("Third"))

if a + b + c == 180:
    print("It is valid triangle")
else:
    print("not valid triangle")
# Out:
# It is valid triangle

# %% [markdown]
# ### 35. Check if two strings are anagrams (simple: check sorted equality).

# %%
df = input()
gh = input()
if sorted(df) == sorted(gh):
    print("It is Anagrams")
else:
    print("It is not anagrams")
# Out:
# It is Anagrams

# %% [markdown]
# ### 36. Determine the type of triangle using sides: acute, right, obtuse.

# %%
tr1 = int(input("side 1"))
tr2 = int(input("side 2"))
tr3 = int(input("side 3"))

if tr1+tr2+tr3 != 180 or tr1<=0 and tr2<=0 and tr3<=0:
    print("Enter correct values")
    
elif tr1 < 90 and tr2 < 90 and tr3 < 90:
    print("It is acute triange")

elif tr1==90 or tr2==90 or tr3 ==90 :
    print("it is right angle triangle")

elif tr1 > 90 or tr2 > 90 or tr3 > 90:
    print("It is Obtuse triangle")
# Out:
# it is right angle triangle

# %% [markdown]
# ### 37. Check if a string is palindrome (case insensitive).

# %%
a = input()
if a == a[::-1]:
    print("String is palindrome")
else:
    print("String is not palindrome")
# Out:
# String is palindrome

# %% [markdown]
# ### 38. Check if the first and last characters of a string are same.

# %%
s = "ssyudjs"

if s[0] == s[-1]:
    print("Yes, first and last characters are the same")
else:
    print("No, they are not the same")
# Out:
# Yes, first and last characters are the same

# %% [markdown]
# ### 39. Check if the sum of digits of a number is divisible by 3.

# %%
a = int(input())
reminder = a % 10
if a % 3 == 0:
    print("Right Answer")
else:
    print("Wrong Answer")
# Out:
# Wrong Answer

# %% [markdown]
# ### 40. Check if a number is Armstrong (3-digit).

# %%
ds = int(input())
if ds == 153:
    print("It is armstrong no")
else:
    print("Not armstrong no")
# Out:
# It is armstrong no

# %% [markdown]
# ### 41. Check if a number has exactly 3 digits.

# %%
a = int(input())
a = str(a)
if len(a) ==3:
    print("you are right")
else:
    print("You are wrong")
# Out:
# You are wrong

# %% [markdown]
# ### 42. Check if a number is perfect (sum of factors equals number).

# %% [markdown]
# ### 43. Compare lengths of two strings and print which is longer.

# %%
a = "Sujit "
b ="Sanket"
if len(a) > len(b):
   print(f"maximum lenght string is {a}")
else:
   print(f"maximum lenght string is {b}")
# Out:
# maximum lenght string is Sankeygygyggyyuuyugt

# %% [markdown]
# ### 44. Check if a list contains duplicates.

# %%
lst = [1, 2, 3, 4, 2]

if len(lst) != len(set(lst)):
    print("The list contains duplicates")
else:
    print("The list does not contain duplicates")
# Out:
# The list contains duplicates

# %% [markdown]
# ### 45. Check if a number is both prime AND even (only possible is 2).

# %%
num = int(input("Enter a number: "))

if num <= 1:
    print("Not Prime")
elif num == 2:
    print("Prime")
elif num % 2 == 0:
    print("Not Prime")
elif num % 3 == 0:
    print("Not Prime")
elif num % 5 == 0:
    print("Not Prime")
else:
    print("Prime")
# Out:
# Prime

# %% [markdown]
# ### 46. Print “YES” if any of the two numbers is zero else print “NO”.

# %%
a = 10
b = 0
if a == 0 or b == 0:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# ### 47. Check if two numbers have the same last digit.

# %%
a = 126
b = 2436
reminder1 = a % 10
reminder2 = b % 10

if reminder1 == reminder2 :
    print("There last digit is")
else:
    print("please add last digit of number is same")
# Out:
# There last digit is

# %% [markdown]
# ### 48. Check if a password contains both letters and digits.

# %%
gf = input()
if gf.isdigit and gf.isalpha:
     print("yes")
else:
     print("no")
# Out:
# yes

# %% [markdown]
# ### 49. Check if a number is “lucky”: sum of first two digits equals last two digits.

# %%
num = 5611

sum_first = (num // 100) // 10 + (num // 100) % 10

last_two = num % 100

if sum_first == last_two:
    print("Lucky No")
else:
    ("Not lucky no")
# Out:
# Lucky No

# %% [markdown]
# ### 50. Check if the absolute difference between two numbers is less than 10

# %%
a = 90
b = 70

if abs (a - b) < 10:
    print("The absolute difference is less than 10")
else:   
    print("The absolute difference is 10 or more")
# Out:
# The absolute difference is 10 or more

# %% [markdown]
# ### 51. Write a program to check if a variable is an integer using isinstance().

# %%
x = input("Enter a value: ")

if x.isdigit():
    x = int(x)
elif isinstance(x, int):
        print("x is an integer")
else:
    print("x is not an integer")
# Out:
# x is not an integer

# %% [markdown]
# ### 52. Check if a given input is a string using isinstance().

# %%
a = "sdfg"

if isinstance(a, str):
    print("a is an String")
else:
    print("a is not an String")
# Out:
# a is an String

# %% [markdown]
# ### 53. Check if a variable is a float and print “Float value found”.

# %%
dc = input("Enter a value: ")

if dc.count(".") == 1 and dc.replace(".", "").isdigit():
    print("Float value found")
else:
    print("Not a float value")
# Out:
# Not a float value

# %% [markdown]
# ### 54. Check if a variable is a list; if yes, print its length.

# %%
x = [10,89,76,45]

if not isinstance(x, list):
    print("not a list")
else:
    print(f"it is a list and its lenght is : {x.__len__()}")
# Out:
# it is a list and its lenght is : 4

# %% [markdown]
# ### 55. Write a program to check if a variable is a tuple; if yes, print the first element.

# %%
tp = (9,1,2,3,4,5)
if type(tp) == tuple:
    print(f"Yes ({tp[0]}) is first value in the tuple")
else:
    print("Please you can creat the tupple")
# Out:
# Yes (9) is first value in the tuple

# %% [markdown]
# ### 56. Check if a variable is a dictionary; if yes, print all keys.

# %%
dic = {"id":1,"Name":"Sujit","Address":"Pushpanagar","Pin":416209}

a = type(dic)
b = dic.keys()

if a == dict:
        print(f"YES variable is in the dictionary : {b}")
else:
    print("Please create dictionary")
# Out:
# YES variable is in the dictionary : dict_keys(['id', 'Name', 'Address', 'Pin'])

# %% [markdown]
# ### 57. Check if a variable is a set; if yes, print the number of elements.

# %%
ag = {"Sujit","Harsh"}
if type(ag) == set:
    print(ag)
else:
    print("please enter create details")
# Out:
# {'Harsh', 'Sujit'}

# %% [markdown]
# ### 58. Check if a variable is a boolean and print “True/False detected”.

# %%
d = True
if type(d) == bool:
    print("Boolean")
else:
    print("not boolean")
# Out:
# Boolean

# %% [markdown]
# ### 59. Write a program to check if a variable is either int OR float (number check).

# %%
sd = 34.5
if type(sd) == int:
    print("It is integer")
elif type(sd) == float:
    print("It is float")
else:
    ("Please check the no")
# Out:
# It is float

# %% [markdown]
# ### 60. Check if a variable is NOT a list (using not isinstance()), and print: “Not a list”.

# %%
x = [10,20,20]

if not isinstance(x, list):
    print("not a list")
else:
    print("it is a list")
# Out:
# it is a list
