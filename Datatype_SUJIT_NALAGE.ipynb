# %%
"""    
DATATYPE

*[1] MUTABLE DATATYPES
    1) LIST
    2) DICTIONARY
    3) SET

*[2] IMMUTABLE DATATYPES
     1) INTEGER
     2) FLOAT
     3) TOUPPLE
     4) STRING
     
"""
# Out:
# '    \nDATATYPE\n\n*[1] MUTABLE DATATYPES\n    1) LIST\n    2) DICTIONARY\n    3) SET\n\n*[2] IMMUTABLE DATATYPES\n     1) INTEGER\n     2) FLOAT\n     3) TOUPPLE\n     4) STRING\n\n'

# %%
lst = [10,20,30] #IT SHOW THE DUPLICATE VALUE
#lst.append(9)

#lst2 = [12,3]
#lst.extend(lst2)
#lst.count()
#lst.copy()
#lst.remove(10)
#lst.pop()
#lst.reverse()
#lst.sort()

# %%
type(lst)
# Out:
# list

# %%
dict = {"NAME":"Sujit","ROLL NO":12}

# %%
#type(dict)
#dict.clear()
#dict.copy()
#dict.pop()
# Out:
# dict

# %%
st = {10,20,90,90} # IT CANNOT SHOW DUPLICATE VALUE & CHANGE THE SEQUENCE

# %%
type(st)
#st.clear()
#st.copy()
#st.pop()
#st.remove(10)
# Out:
# set

# %%
a =12

# %%
type(a)
# Out:
# int

# %%
flt =10.2

# %%
type(flt)
# Out:
# float

# %%
s = "sujit nalage"

# %%
type(s)

# s.capitalize - First letetr capital
# s.count() - it show the count in the specific character in the string
# s.endswith()- in this () you can add specific character if the character is ends with string then returs true else false
# s.startswith()-start string with the specific letter then it returns true otherwise false.
# s.lower() - string return in lower case
# s.upper() - string return in upper case
# s.isupper() - if string is in upper case it returns true else false
# s.islower() - if string is in lower case it returns true else false
# s.title() - in the string each word first letter captal
# Out:
# str

# %%
tp = (10,12,23,34)

# %%
type(tp)
# tp.count(10) - it show the count of 10 numbers
# Out:
# tuple
