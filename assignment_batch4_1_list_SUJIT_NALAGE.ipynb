# %% [markdown]
# # Basic List Operations

# %% [markdown]
# 1. Create a list of 5 numbers and add a new number to the end.

# %%
lst = [1,2,3,4,5]
lst.append(6)
lst
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 2. Make a list of fruits and insert a fruit at the second position.

# %%
fruits = ["Mango","Bnana","Apple","Orange"]
fruits.insert(1,"Greps")  # insert one more fruit
fruits
# Out:
# ['Mango', 'Greps', 'Bnana', 'Apple', 'Orange']

# %% [markdown]
# 3. Create a list of names and remove one name from the list.

# %%
stud = ["SUjit","Harsh","Sanket"]
stud.remove("Sanket") # remove the spesific name
stud
# Out:
# ['SUjit', 'Harsh']

# %% [markdown]
# 4. Create a list of 4 items and change the value at index 2.

# %%
items = [1,2,3,4]
items[2] = 5 #it can change the value of index no 2
items
# Out:
# [1, 2, 5, 4]

# %% [markdown]
# 5. Make a list of numbers and print only the first three elements.

# %%
num = [1,2,3,4,5,6]
num[0:3]
# Out:
# [1, 3, 5]

# %% [markdown]
# 6. Create a list of colors and find the index of a specific color.

# %%
colour = ["White","Orange","Green","Yello"]
colour.index("Green")
# Out:
# 2

# %% [markdown]
# 7. Create a list of 10 numbers and print how many times “5” appears.

# %%
a = [1,2,5,3,5,6,7,5,9,5]
a.count(5)
# Out:
# 4

# %% [markdown]
# 8. Make a list of 6 items and delete the item at index 3.

# %%
b = [1,2,3,4,5,6]
del b[3]  # delete the no where index is 4
b
# Out:
# [1, 2, 3, 5, 6]

# %% [markdown]
# 9. Create a list of animals and add three more animals using extend().

# %%
c = ["Lion","Elephent","Tiger"]
c.extend(["Dog","Cat","Zebra"])
c
# Out:
# ['Lion', 'Elephent', 'Tiger', 'Dog', 'Cat', 'Zebra']

# %% [markdown]
# 10. Create a list and remove the last item using pop().

# %%
d = [1,2,3,4,5]
d.pop()
d
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# 11. Create a list of prices and sort them in ascending order.

# %%
e = [100,500,200,1000,20,500]
e.sort()
e
# Out:
# [20, 100, 200, 500, 500, 1000]

# %% [markdown]
# 12. Make a list of countries and reverse the order of the list.

# %%
f = ["India","America","France","Canada"]
f.reverse()
f
# Out:
# ['Canada', 'France', 'America', 'India']

# %% [markdown]
# 13. Create a list of words and check if “apple” is in the list.

# %%
g = ["Apple","Banana","Orange"]
g.__contains__("Apple")
# Out:
# True

# %% [markdown]
# 14. Create a list of numbers and print the largest and smallest number.

# %%
h = [10,23,34,56,78,1]
print(max(h),"Is a largest no")
print(min(h),"Is a smallest no")
# Out:
# 78 Is a largest no
# 1 Is a smallest no

# %% [markdown]
# 15. Make a list of 5 items and print each item using a loop.

# %%
#i dont understand this question

# %% [markdown]
# 16. Create two lists and combine them into one list.

# %%
i = [1,2,3,4]
j = [5,6,7,8]
print(i + j )
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# 17. Make a list and replace the last item with a new value.

# %%
k = ["SUJIT","SANKET","SAGAR"]
k[2] = "VISHAL"
k
# Out:
# ['SUJIT', 'SANKET', 'VISHAL']

# %% [markdown]
# 18. Create a list of numbers and print only the even numbers.

# %%
even = [1,2,3,4,5,6,7,8,9]
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# 19. Create a list and clear all items from the list.

# %%
a = [10,20,30,40,50]
a.clear
# Out:
# <function list.clear()>

# %% [markdown]
# 20. Create a list of 5 values and copy it into another list.

# %%
list1 = [1,2,3,4,5]
list2 = list1
list2
# Out:
# [1, 2, 3, 4, 5]
